# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score
import random

# %%
treinamento = pd.read_csv("/content/drive/MyDrive/Arquivos Colab/Titanic/train.csv")
treinamento.head(7)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
#
# [7 rows x 12 columns]

# %% [markdown]
# - sibsp é o número de irmãos e cônjuges da pessoa
# - parch é o número de pais e filhos da pessoa
# - fare é a tarifa do passageiro
# - embarked é o porto de embarque

# %%
treinamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Cabin tem a maioria dos valores faltando, Age alguns valores faltando, Embarked poucos valores faltando.

# %% [markdown]
# - Sex é uma categoria binária
# - Embarked é uma categoria
# - Name é texto
# - Survived é uma categoria binária

# %% [markdown]
# O único valor numérico contínuo é o fare

# %%
treinamento['Survived'].value_counts().plot.pie(autopct='%1.2f%%')

# %% [markdown]
# 61.62% Morreram

# %% [markdown]
# Correlação entre fare e survived

# %%
plt.figure(figsize=(16,6))
plt.title('fare/survived')
sns.barplot(x=treinamento['Survived'], y=treinamento['Fare'])
plt.xlabel("Survived")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# Problemas encontrados:
# - Valores Faltando
# - Valores númericos de diferentes tipos
# - Grande quantidade de valores nominais
